# %% [markdown]
# <b> Importing Modules </b>

# %%
#Importing libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Reading data files from the system.
Df = pd.read_csv(r"C:\Users\Helenasec\A4.csv")

# %%
Df.head()
# Out:
#    Glucose  BloodPressure  DiabetesPedigreeFunction  Outcome
# 0      148             72                     0.627        1
# 1       85             66                     0.351        0
# 2      183             64                     0.672        1
# 3       89             66                     0.167        0
# 4      137             40                     2.288        1

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Glucose                   132 non-null    int64
#  1   BloodPressure             132 non-null    int64
#  2   DiabetesPedigreeFunction  132 non-null    float64
#  3   Outcome                   132 non-null    int64
# dtypes: float64(1), int64(3)
# memory usage: 4.2 KB

# %% [markdown]
# <b> Data Preprocessing </b>

# %% [markdown]
# <b> Checking for null values </b>

# %%
#Returning total null/missing values in 'df'.
Df.isnull().sum()
# Out:
# Glucose                     0
# BloodPressure               0
# DiabetesPedigreeFunction    0
# Outcome                     0
# dtype: int64

# %%
print("No missing values found")
# Out:
# No missing values found

# %% [markdown]
# <b> Checking for outliers </b>

# %%
#Plotting boxplots.
plt.figure(figsize=(20, 12))
plt.subplot(2,3,1)
sns.boxplot(y= 'Glucose',  data = Df, color="0.25")
plt.subplot(2,3,2)
sns.boxplot(y= 'BloodPressure', data = Df, palette="Greens")
plt.subplot(2,3,3)
sns.boxplot(y= 'DiabetesPedigreeFunction', data = Df, color="Orange")
plt.subplot(2,3,4)
sns.boxplot(y= 'Outcome', data = Df, palette="Blues")

# %% [markdown]
# <b> Data Visulaization </b>

# %%
#Plotting a heatmap.
plt.figure(figsize = (40,40))
sns.heatmap(Df.corr(), annot = True,cmap="YlGnBu")
plt.show()

# %%
Df.hist(figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026154E015B0>,
# ...
#       dtype=object)

# %%
sns.distplot(Df)

# %% [markdown]
# <b> Data Preprocessing </b>

# %% [markdown]
# <b>Building models and comapring</b>

# %%
#Dropping unnecessary attributes.
X = Df.drop(['Outcome'], axis=1)
Y= df['Outcome']

# %%
#Importing libraries.
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, train_size=0.7, test_size=0.3, random_state =50)

# %% [markdown]
# <b> Logistic Regression </b>

# %%
#Training using 'LR'.
Lr = LogisticRegression()

#Adjusting weights of the data.
Lr.fit(X_train, y_train)

#Returning a label for each object using .'predict()' function.
YPred = Lr.predict(X_test)

#Rouding up the score.
Acc_lr = round(Lr.score(X_train, y_train) * 100, 2)

# %% [markdown]
# <b> Stochastic Gradient Descent </b>

# %%
#Training using 'SGD'.
Sgd = linear_model.SGDClassifier(max_iter=5, tol=None)

#Adjusting weights of the data.
Sgd.fit(X_train, y_train)

#Returning a label for each object using .'predict()' function.
YPred = Sgd.predict(X_test)

#Calculating score using '.score()' function.
Sgd.score(X_train, y_train)

#Rouding up the score.
Acc_sgd = round(Sgd.score(X_train, y_train) * 100, 2)

# %% [markdown]
# <b> Gaussian Naive Bayes </b>

# %%
#Training using 'GNB'.
Gaussian = GaussianNB() 

#Adjusting weights of the data.
Gaussian.fit(X_train, y_train)  

#Returning a label for each object using .'predict()' function.
YPred = Gaussian.predict(X_test) 

#Rouding up the score.
Acc_gaussian = round(Gaussian.score(X_train, y_train) * 100, 2)

# %% [markdown]
# <b> Model Evaluation </b>

# %%
print(Acc_lr)
print(Acc_sgd)
print(Acc_gaussian)
# Out:
# 67.39
# 64.13
# 72.83

# %%
print("Gaussian Naive Bayes has greatest score of 72.83 so we choose this model")
# Out:
# Gaussian Naive Bayes has greatest score of 72.83 so we choose this model
