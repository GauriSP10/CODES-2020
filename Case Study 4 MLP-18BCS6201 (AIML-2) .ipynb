# %% [markdown]
# <h1> Worksheet </h1>

# %%
#Importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data_train = pd.read_csv("D://Dip pictures/Training_Set.csv")
data_train.head()
# Out:
#    Attribute 1 (a1)  Attribute 2 (a2)  Class Label
# 0                 2                11            2
# 1                 2                13            2
# 2                 2                15            2
# 3                 2                27            1
# 4                 2                39            1

# %%
data_train.shape
# Out:
# (30, 3)

# %%
data_train.isnull().sum()
# Out:
# Attribute 1 (a1)    0
# Attribute 2 (a2)    0
# Class Label         0
# dtype: int64

# %% [markdown]
# <b> Getting data ready </b>

# %%
# Putting feature variable to X
X = data_train.drop('Class Label',axis=1)

# Putting response variable to y
y = data_train['Class Label']

# %%
data_test = pd.read_csv("D://Dip pictures/Validation_Set.csv")
data_test.drop(['Unnamed: 4','Unnamed: 5', 'Unnamed: 6'],inplace = True, axis = 1)
X_test = data_test.drop(["True Class Label","Class Label as predicted by the decision tree"], axis = 1)
y_test = data_test["True Class Label"]

# %% [markdown]
# <b> Decision Tree Classifier </b>

# %%
# Importing decision tree classifier from sklearn library
from sklearn.tree import DecisionTreeClassifier

# Fitting the decision tree
dt = DecisionTreeClassifier(max_depth=3)
dt.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
y_pred = dt.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.50      1.00      0.67         1
#            2       1.00      0.67      0.80         3
#
#     accuracy                           0.75         4
#    macro avg       0.75      0.83      0.73         4
# weighted avg       0.88      0.75      0.77         4

# %%
# Confusion matrix and accuracy
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
# Out:
# [[1 0]
#  [1 2]]
# 0.75

# %%
# Importing required packages for visualization
from IPython.display import Image 
from sklearn.tree import export_graphviz
import pydotplus, graphviz
from six import StringIO

# Putting features
features = list(data_train.columns[1:])
features
# Out:
# ['Attribute 2 (a2)', 'Class Label']

# %% [markdown]
# <b> Hyperparameter Tuning </b>

# %%
# Create the parameter grid 
param_grid = {'max_depth':range(0,20,2),
    'min_samples_leaf' : range(0,5),
    'min_samples_split' : range(0,10),
    'criterion':['gini']
}

n_folds = 5

# Instantiate the grid search model
dtree = DecisionTreeClassifier()
grid_search = GridSearchCV(estimator = dtree, param_grid = param_grid, 
                          cv = n_folds, verbose = 1)

# Fit the grid search to the data
grid_search.fit(X,y)
# Out:
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\sklearn\model_selection\_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\sklearn\tree\_classes.py", line 894, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\sklearn\tree\_classes.py", line 217, in fit
#     % self.min_samples_leaf)
# ...

# %%
best_score = grid_search.best_score_
best_hyper = grid_search.best_params_

# %%
print("score : {} \n params : {}".format(best_score,best_hyper))
# Out:
# score : 0.7
#  params : {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
# model with optimal hyperparameters
clf_gini = DecisionTreeClassifier(criterion = "gini", 
                                  random_state = 100,
                                  max_depth=2, 
                                  min_samples_leaf=1,
                                  min_samples_split=2)
clf_gini.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=100)

# %% [markdown]
# <b> Evaluation </b>

# %%
y_pred = clf_gini.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.33      1.00      0.50         1
#            2       1.00      0.33      0.50         3
#
#     accuracy                           0.50         4
#    macro avg       0.67      0.67      0.50         4
# weighted avg       0.83      0.50      0.50         4
